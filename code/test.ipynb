# %%
import julia

julia_path = "/Applications/Julia-1.9.app/Contents/Resources/julia/bin/julia"
project_path = "/Users/stijnrommens/GithubProjects/GM_pressure/code/"
script_path = "/Users/stijnrommens/GithubProjects/GM_pressure/code/main.jl"

julia.install(julia = julia_path)
jl = julia.Julia(runtime = julia_path, compiled_modules=False)
# Out:
# [ Info: Julia version info
# Julia Version 1.9.3
# Commit bed2cd540a1 (2023-08-24 14:43 UTC)
# Build Info:
#   Official https://julialang.org/ release
# Platform Info:
#   OS: macOS (x86_64-apple-darwin22.4.0)
#   uname: Darwin 23.2.0 Darwin Kernel Version 23.2.0: Wed Nov 15 21:54:10 PST 2023; root:xnu-10002.61.3~2/RELEASE_X86_64 x86_64 i386
#   CPU: Intel(R) Core(TM) i5-8210Y CPU @ 1.60GHz:
#               speed         user         nice          sys         idle          irq
#        #1  1600 MHz     231267 s          0 s     147915 s     376826 s          0 s
#        #2  1600 MHz      68761 s          0 s      37404 s     652154 s          0 s
#        #3  1600 MHz     227329 s          0 s     102945 s     426680 s          0 s
#        #4  1600 MHz      61708 s          0 s      34228 s     662426 s          0 s
#   Memory: 8.0 GB (298.80078125 MB free)
#   Uptime: 305576.0 sec
#   Load Avg:  4.24658203125  3.46044921875  3.34619140625
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-14.0.6 (ORCJIT, skylake)
#   Threads: 1 on 4 virtual cores
# Environment:
#   TERM = xterm-color
#   PATH = /Users/stijnrommens/opt/anaconda3/bin:/Library/Frameworks/Python.framework/Versions/3.10/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin
#   XPC_FLAGS = 0x0
#   HOME = /Users/stijnrommens
# [ Info: Julia executable: /Applications/Julia-1.9.app/Contents/Resources/julia/bin/julia
# [ Info: Trying to import PyCall...
# ┌ Warning: PyCall is already installed.  However, you may have trouble using
# │ this Python executable because it is statically linked to libpython.
# │
# │ For more information, see:
# │     https://pyjulia.readthedocs.io/en/latest/troubleshooting.html
# │
# │ Python executable:
# │     /Users/stijnrommens/opt/anaconda3/bin/python
# │ Julia executable:
# │     /Applications/Julia-1.9.app/Contents/Resources/julia/bin/julia
# └ @ Main ~/opt/anaconda3/lib/python3.9/site-packages/julia/install.jl:90

# %%
from julia import Main
Main.include(script_path)
# Out:
#           WELCOME TO:
#   Activating project at `~/GithubProjects/GM_pressure/code`
# WARNING: replacing module Check_Mod.
# <PyCall.jlwrap test>
# ------------------------------
#  🫧🫧      🫧🫧🫧  🫧      🫧
#  🫧  🫧  🫧        🫧🫧  🫧🫧
#  🫧🫧    🫧  🫧🫧  🫧🫧🫧🫧🫧
#  🫧      🫧    🫧  🫧  🫧  🫧
#  🫧        🫧🫧    🫧      🫧
# ------------------------------

# %%
import numpy as np
C = 0.1
my_ions = [[C, +1.0, 2.3e-10],[C, -1.0, 3.2e-10]]

Main.test()
# Main.eval("main()")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [20], in <cell line: 5>()
#       2 C = 0.1
#       3 my_ions = [[C, +1.0, 2.3e-10],[C, -1.0, 3.2e-10]]
# ----> 5 Main.test()
#
# RuntimeError: <PyCall.jlwrap (in a Julia function called from Python)
# JULIA: MethodError: no method matching _method_instances(::Type{typeof(ArrayInterface.promote_eltype)}, ::Type{Tuple{Type{Vector{Float64}}, Type{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}})
# The applicable method may be too new: running in world age 44169, while current world is 77308.
#
# Closest candidates are:
#   _method_instances(::Any, ::Any) (method too new to be called from this world context.)
#    @ Tricks ~/.julia/packages/Tricks/7oAyo/src/Tricks.jl:150
#
# Stacktrace:
#   [1] #s225#1
#     @ ~/.julia/packages/Tricks/7oAyo/src/Tricks.jl:16 [inlined]
#   [2] var"#s225#1"(T::Any, ::Any, f::Any, t::Any)
#     @ Tricks ./none:0
#   [3] (::Core.GeneratedFunctionStub)(::Any, ::Vararg{Any})
#     @ Core ./boot.jl:602
#   [4] promote_f(f::ODEFunction{true, SciMLBase.AutoSpecialize, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, #unused#::Val{SciMLBase.AutoSpecialize}, u0::Vector{Float64}, p::Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, t::Float64)
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:1171
#   [5] get_concrete_problem(prob::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, ODEFunction{true, SciMLBase.AutoSpecialize, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, isadapt::Bool; kwargs::Base.Pairs{Symbol, Any, NTuple{4, Symbol}, NamedTuple{(:u0, :p, :abstol, :reltol), Tuple{Vector{Float64}, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:1112
#   [6] get_concrete_problem
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:1106 [inlined]
#   [7] solve_up(prob::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, ODEFunction{true, SciMLBase.AutoSpecialize, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, sensealg::Nothing, u0::Vector{Float64}, p::Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, args::RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}; kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:1017
#   [8] solve_up
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:993 [inlined]
#   [9] solve(prob::ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, ODEFunction{true, SciMLBase.AutoSpecialize, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, args::RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}; sensealg::Nothing, u0::Nothing, p::Nothing, wrap::Val{true}, kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:930
#  [10] (::BoundaryValueDiffEq.var"#loss!#16"{Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}}, BVProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, typeof(bc!), SciMLBase.StandardBVProblem, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}}, Shooting{RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}, TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}}, typeof(bc!), Bool})(resid::Vector{Float64}, u0::Vector{Float64}, p::Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64})
#     @ BoundaryValueDiffEq ~/.julia/packages/BoundaryValueDiffEq/qCOzF/src/solve.jl:7
#  [11] NonlinearFunction
#     @ ~/.julia/packages/SciMLBase/szsYq/src/scimlfunctions.jl:2267 [inlined]
#  [12] __init(::NonlinearProblem{Vector{Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, NonlinearFunction{true, SciMLBase.FullSpecialize, BoundaryValueDiffEq.var"#loss!#16"{Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}}, BVProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, typeof(bc!), SciMLBase.StandardBVProblem, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}}, Shooting{RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}, TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}}, typeof(bc!), Bool}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardNonlinearProblem}, ::TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}; alias_u0::Bool, maxiters::Int64, abstol::Float64, internalnorm::Function, kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol}, NamedTuple{(:reltol,), Tuple{Float64}}})
#     @ NonlinearSolve ~/.julia/packages/NonlinearSolve/49XeP/src/trustRegion.jl:303
#  [13] __init
#     @ ~/.julia/packages/NonlinearSolve/49XeP/src/trustRegion.jl:286 [inlined]
#  [14] #init_call#30
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:475 [inlined]
#  [15] init_call
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:453 [inlined]
#  [16] init_up(prob::NonlinearProblem{Vector{Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, NonlinearFunction{true, SciMLBase.FullSpecialize, BoundaryValueDiffEq.var"#loss!#16"{Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}}, BVProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, typeof(bc!), SciMLBase.StandardBVProblem, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}}, Shooting{RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}, TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}}, typeof(bc!), Bool}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardNonlinearProblem}, sensealg::Nothing, u0::Vector{Float64}, p::Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, args::TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}; kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:525
#  [17] init_up
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:495 [inlined]
#  [18] #init#31
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:488 [inlined]
#  [19] init
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:479 [inlined]
#  [20] __solve(::NonlinearProblem{Vector{Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, NonlinearFunction{true, SciMLBase.FullSpecialize, BoundaryValueDiffEq.var"#loss!#16"{Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}}, BVProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, typeof(bc!), SciMLBase.StandardBVProblem, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}}, Shooting{RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}, TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}}, typeof(bc!), Bool}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardNonlinearProblem}, ::TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}; kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}})
#     @ NonlinearSolve ~/.julia/packages/NonlinearSolve/49XeP/src/NonlinearSolve.jl:32
#  [21] __solve
#     @ ~/.julia/packages/NonlinearSolve/49XeP/src/NonlinearSolve.jl:29 [inlined]
#  [22] #solve_call#34
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:559 [inlined]
#  [23] solve_call
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:529 [inlined]
#  [24] solve_up(prob::NonlinearProblem{Vector{Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, NonlinearFunction{true, SciMLBase.FullSpecialize, BoundaryValueDiffEq.var"#loss!#16"{Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}}, BVProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, typeof(bc!), SciMLBase.StandardBVProblem, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}}, Shooting{RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}, TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}}, typeof(bc!), Bool}, LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED_NO_TIME), Nothing, Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardNonlinearProblem}, sensealg::Nothing, u0::Vector{Float64}, p::Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, args::TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}; kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:1028
#  [25] solve_up
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:993 [inlined]
#  [26] #solve#41
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:987 [inlined]
#  [27] solve
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:977 [inlined]
#  [28] __solve(prob::BVProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, typeof(bc!), SciMLBase.StandardBVProblem, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}}, alg::Shooting{RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}, TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}}; kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}})
#     @ BoundaryValueDiffEq ~/.julia/packages/BoundaryValueDiffEq/qCOzF/src/solve.jl:11
#  [29] __solve
#     @ ~/.julia/packages/BoundaryValueDiffEq/qCOzF/src/solve.jl:1 [inlined]
#  [30] #solve_call#34
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:559 [inlined]
#  [31] solve_up(prob::BVProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, typeof(bc!), SciMLBase.StandardBVProblem, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}}, sensealg::Nothing, u0::Vector{Float64}, p::Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, args::Shooting{RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}, TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}}; kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:1020
#  [32] solve_up
#     @ ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:993 [inlined]
#  [33] solve(prob::BVProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Tuple{NTuple{6, Float64}, Tuple{NTuple{4, Float64}, NTuple{4, Float64}}, Float64}, BVPFunction{true, SciMLBase.FullSpecialize, typeof(mPBE!), typeof(bc!), LinearAlgebra.UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing, Nothing}, typeof(bc!), SciMLBase.StandardBVProblem, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}}, args::Shooting{RadauIIA5{0, false, Nothing, typeof(OrdinaryDiffEq.DEFAULT_PRECS), Val{:forward}, true, nothing, Nothing, Rational{Int64}, Rational{Int64}}, TrustRegion{0, true, Val{:forward}, Nothing, typeof(NonlinearSolve.DEFAULT_PRECS), true, nothing, Rational{Int64}}}; sensealg::Nothing, u0::Nothing, p::Nothing, wrap::Val{true}, kwargs::Base.Pairs{Symbol, Float64, Tuple{Symbol, Symbol}, NamedTuple{(:abstol, :reltol), Tuple{Float64, Float64}}})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/s433k/src/solve.jl:930
#  [34] main(list::Bool; print_flag::Bool, T::Float64, h::Float64, ionS::Float64, ion_tot::Tuple{}, elc::Float64, Avog::Float64, epsilon_w::Float64, epsilon_o::Float64, abstol::Float64, reltol::Float64, fun::typeof(mPBE!), bc::typeof(bc!))
#     @ Main ~/GithubProjects/GM_pressure/code/main.jl:50
#  [35] main (repeats 2 times)
#     @ ~/GithubProjects/GM_pressure/code/main.jl:16 [inlined]
#  [36] test()
#     @ Main ~/GithubProjects/GM_pressure/code/main.jl:74
#  [37] #invokelatest#2
#     @ ./essentials.jl:819 [inlined]
#  [38] invokelatest(::Any)
#     @ Base ./essentials.jl:816
#  [39] _pyjlwrap_call(f::Function, args_::Ptr{PyCall.PyObject_struct}, kw_::Ptr{PyCall.PyObject_struct})
#     @ PyCall ~/.julia/packages/PyCall/1gn3u/src/callback.jl:28
#  [40] pyjlwrap_call(self_::Ptr{PyCall.PyObject_struct}, args_::Ptr{PyCall.PyObject_struct}, kw_::Ptr{PyCall.PyObject_struct})
#     @ PyCall ~/.julia/packages/PyCall/1gn3u/src/callback.jl:44>
